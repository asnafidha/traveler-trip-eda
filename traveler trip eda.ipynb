# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cc=pd.read_csv(r"C:\Users\User\Downloads\archive (6)\Travel details dataset.csv")
cc
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 0          1              London, UK   5/1/2023   5/8/2023              7.0
# 1          2        Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2          3         Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3          4           New York, USA  8/15/2023  8/29/2023             14.0
# 4          5            Tokyo, Japan  9/10/2023  9/17/2023              7.0
# ..       ...                     ...        ...        ...              ...
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
# ...

# %%
cc.head()
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023              7.0
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith          35.0            Male             American
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   Accommodation type Accommodation cost Transportation type  \
# 0              Hotel               1200              Flight
# ...

# %%
#Checking if we have any NaN values
cc.isnull().sum()
# Out:
# Trip ID                 0
# Destination             2
# Start date              2
# End date                2
# Duration (days)         2
# Traveler name           2
# Traveler age            2
# Traveler gender         2
# Traveler nationality    2
# Accommodation type      2
# Accommodation cost      2
# Transportation type     3
# Transportation cost     3
# dtype: int64

# %%
cc = cc.dropna()

# %%
cc["Transportation type"].unique()
# Out:
# array(['Flight', 'Train', 'Plane', 'Bus', 'Car rental', 'Subway', 'Car',
#        'Ferry', 'Airplane'], dtype=object)

# %%
#Let's make our data more simple
#cc["Transportation type"].replace({"Flight":"Plane", "Airplane": "Plane"}, inplace=True) 
import pandas as pd

# Assuming cc is your DataFrame
cc["Transportation type"] = cc["Transportation type"].replace({"Flight": "Plane", "Airplane": "Plane"})
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               136 non-null    int64
#  1   Destination           136 non-null    object
#  2   Start date            136 non-null    object
#  3   End date              136 non-null    object
#  4   Duration (days)       136 non-null    float64
#  5   Traveler name         136 non-null    object
#  6   Traveler age          136 non-null    float64
#  7   Traveler gender       136 non-null    object
#  8   Traveler nationality  136 non-null    object
#  9   Accommodation type    136 non-null    object
#  10  Accommodation cost    136 non-null    int32
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    int32
# dtypes: float64(2), int32(2), int64(1), object(8)
# memory usage: 13.8+ KB
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               136 non-null    int64
#  1   Destination           136 non-null    object
#  2   Start date            136 non-null    object
#  3   End date              136 non-null    object
#  4   Duration (days)       136 non-null    float64
#  5   Traveler name         136 non-null    object
#  6   Traveler age          136 non-null    float64
#  7   Traveler gender       136 non-null    object
#  8   Traveler nationality  136 non-null    object
#  9   Accommodation type    136 non-null    object
#  10  Accommodation cost    136 non-null    int32
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    int32
# dtypes: float64(2), int32(2), int64(1), object(8)
# memory usage: 13.8+ KB

# %%
#Let's keep our cost features more consistent
#cc["Transportation cost"] = cc["Transportation cost"].replace("[^\d]+", "", regex=True)
#cc["Accommodation cost"] = cc["Accommodation cost"].replace("[^\d]+", "", regex=True)

#Turn them integers
#cc["Transportation cost"] = cc["Transportation cost"].astype(int)
#cc["Accommodation cost"] = cc["Accommodation cost"].astype(int)#

import pandas as pd

# Assuming cc is your DataFrame
cc["Transportation cost"] = cc["Transportation cost"].replace("[^\d]+", "", regex=True)
cc["Accommodation cost"] = cc["Accommodation cost"].replace("[^\d]+", "", regex=True)

# Use .loc to modify the original DataFrame
cc.loc[:, "Transportation cost"] = cc["Transportation cost"].astype(int)
cc.loc[:, "Accommodation cost"] = cc["Accommodation cost"].astype(int)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5404\3280655820.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc["Transportation cost"] = cc["Transportation cost"].replace("[^\d]+", "", regex=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_5404\3280655820.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc["Accommodation cost"] = cc["Accommodation cost"].replace("[^\d]+", "", regex=True)

# %%
import pandas as pd

# Assuming cc is your DataFrame
cc.loc[:, "Transportation cost"] = cc["Transportation cost"].replace("[^\d]+", "", regex=True)
cc.loc[:, "Accommodation cost"] = cc["Accommodation cost"].replace("[^\d]+", "", regex=True)

# %%
plt.figure(figsize=(16,10), dpi=100)
sns.histplot(data=cc, x="Transportation cost", y="Transportation type" , hue="Duration (days)")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(8,10), dpi=100)
sns.histplot(data=cc, x="Traveler age", y="Traveler nationality" , hue="Traveler gender")
plt.xticks(rotation=90);

#We can say that most of the old travellers are male and females prefer to travel younger.

# %%
plt.figure(figsize=(10,6), dpi=100)
sns.countplot(data=cc, x="Traveler nationality")
plt.xticks(rotation=90);

# %%
cc.head()
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023              7.0
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith          35.0            Male             American
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   Accommodation type  Accommodation cost Transportation type  \
# 0              Hotel                1200               Plane
# ...

# %%
cc["Total Cost ($)"] = cc["Accommodation cost"] + cc["Transportation cost"]
cc["Total Cost ($)"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5404\4251650021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc["Total Cost ($)"] = cc["Accommodation cost"] + cc["Transportation cost"]
# 0      1800
# 1      1300
# 2      1700
# 3      3000
# 4       900
#        ...
# 134    4500
# 135    8000
# 136    3000
# 137    8500
# 138    9500
# Name: Total Cost ($), Length: 136, dtype: int32

# %%
#Places by total expenditure
plt.figure(figsize=(10,16), dpi=100)
sns.histplot(data=cc.sort_values(by="Total Cost ($)", ascending=True), x="Total Cost ($)", y="Destination" , hue="Duration (days)")
plt.xticks(rotation=90);
